# %% [markdown]
# <a href="https://colab.research.google.com/github/SuryARavichan/PANDAS/blob/main/DATAFRAMES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(101)
mydata = np.random.randint(0,101,(4,3))

# %%
mydata
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]])

# %%
myindex = ['ca','at','gr','ny']

# %%
mycolumns = ['jan','feb','mar','apr']

# %%
df = pd.DataFrame(data=mydata,index=myindex)

# %%
df
# Out:
#      0   1   2
# ca  95  11  81
# at  70  63  87
# gr  75   9  77
# ny  40   4  63

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, ca to ny
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       4 non-null      int64
#  1   1       4 non-null      int64
#  2   2       4 non-null      int64
# dtypes: int64(3)
# memory usage: 128.0+ bytes

# %%
pwd
# Out:
# '/content'

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dc6417c1-1be5-4847-98eb-25869a9f186e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dc6417c1-1be5-4847-98eb-25869a9f186e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tips.csv to tips.csv

# %%
df = pd.read_csv('tips.csv')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.head(15)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.tail(20)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 224       13.42  1.58    Male    Yes   Fri   Lunch     2
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 227       20.45  3.00    Male     No   Sat  Dinner     4
# 228       13.28  2.72    Male     No   Sat  Dinner     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3
# 232       11.61  3.39    Male     No   Sat  Dinner     2
# 233       10.77  1.47    Male     No   Sat  Dinner     2
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.describe().transpose()
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
df['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
type(df['total_bill'])
# Out:
# pandas.core.series.Series

# %%
mycols = ['day','sex','tip']
df[mycols]
# Out:
#       day     sex   tip
# 0     Sun  Female  1.01
# 1     Sun    Male  1.66
# 2     Sun    Male  3.50
# 3     Sun    Male  3.31
# 4     Sun  Female  3.61
# ..    ...     ...   ...
# 239   Sat    Male  5.92
# 240   Sat  Female  2.00
# 241   Sat    Male  2.00
# 242   Sat    Male  1.75
# 243  Thur  Female  3.00
#
# [244 rows x 3 columns]

# %%
df['tip percentage'] = 100 * df['tip'] / df['total_bill']

# %%
df['tip percentage']
# Out:
# 0       5.944673
# 1      16.054159
# 2      16.658734
# 3      13.978041
# 4      14.680765
#          ...
# 239    20.392697
# 240     7.358352
# 241     8.822232
# 242     9.820426
# 243    15.974441
# Name: tip percentage, Length: 244, dtype: float64

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  tip percentage
# 0         16.99  1.01  Female     No   Sun  Dinner     2        5.944673
# 1         10.34  1.66    Male     No   Sun  Dinner     3       16.054159
# 2         21.01  3.50    Male     No   Sun  Dinner     3       16.658734
# 3         23.68  3.31    Male     No   Sun  Dinner     2       13.978041
# 4         24.59  3.61  Female     No   Sun  Dinner     4       14.680765
# ..          ...   ...     ...    ...   ...     ...   ...             ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3       20.392697
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2        7.358352
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2        8.822232
# 242       17.82  1.75    Male     No   Sat  Dinner     2        9.820426
# 243       18.78  3.00  Female     No  Thur  Dinner     2       15.974441
#
# [244 rows x 8 columns]

# %%
df.shape
# Out:
# (244, 8)

# %%
df.shape[0]
# Out:
# 244

# %%
df.shape[1]
# Out:
# 8

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.set_index('smoker')
# Out:
#         total_bill   tip     sex   day    time  size  tip percentage
# smoker
# No           16.99  1.01  Female   Sun  Dinner     2        5.944673
# No           10.34  1.66    Male   Sun  Dinner     3       16.054159
# No           21.01  3.50    Male   Sun  Dinner     3       16.658734
# No           23.68  3.31    Male   Sun  Dinner     2       13.978041
# No           24.59  3.61  Female   Sun  Dinner     4       14.680765
# ...            ...   ...     ...   ...     ...   ...             ...
# No           29.03  5.92    Male   Sat  Dinner     3       20.392697
# Yes          27.18  2.00  Female   Sat  Dinner     2        7.358352
# Yes          22.67  2.00    Male   Sat  Dinner     2        8.822232
# No           17.82  1.75    Male   Sat  Dinner     2        9.820426
# No           18.78  3.00  Female  Thur  Dinner     2       15.974441
#
# [244 rows x 7 columns]

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  tip percentage
# 0         16.99  1.01  Female     No   Sun  Dinner     2        5.944673
# 1         10.34  1.66    Male     No   Sun  Dinner     3       16.054159
# 2         21.01  3.50    Male     No   Sun  Dinner     3       16.658734
# 3         23.68  3.31    Male     No   Sun  Dinner     2       13.978041
# 4         24.59  3.61  Female     No   Sun  Dinner     4       14.680765
# ..          ...   ...     ...    ...   ...     ...   ...             ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3       20.392697
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2        7.358352
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2        8.822232
# 242       17.82  1.75    Male     No   Sat  Dinner     2        9.820426
# 243       18.78  3.00  Female     No  Thur  Dinner     2       15.974441
#
# [244 rows x 8 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  tip percentage
# 0       16.99  1.01  Female     No  Sun  Dinner     2        5.944673
# 1       10.34  1.66    Male     No  Sun  Dinner     3       16.054159
# 2       21.01  3.50    Male     No  Sun  Dinner     3       16.658734
# 3       23.68  3.31    Male     No  Sun  Dinner     2       13.978041
# 4       24.59  3.61  Female     No  Sun  Dinner     4       14.680765

# %%
df.info
# Out:
# <bound method DataFrame.info of      total_bill   tip     sex smoker   day    time  size  tip percentage
# 0         16.99  1.01  Female     No   Sun  Dinner     2        5.944673
# 1         10.34  1.66    Male     No   Sun  Dinner     3       16.054159
# 2         21.01  3.50    Male     No   Sun  Dinner     3       16.658734
# 3         23.68  3.31    Male     No   Sun  Dinner     2       13.978041
# 4         24.59  3.61  Female     No   Sun  Dinner     4       14.680765
# ..          ...   ...     ...    ...   ...     ...   ...             ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3       20.392697
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2        7.358352
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2        8.822232
# 242       17.82  1.75    Male     No   Sat  Dinner     2        9.820426
# 243       18.78  3.00  Female     No  Thur  Dinner     2       15.974441
#
# [244 rows x 8 columns]>

# %%
df = df.set_index('smoker')

# %%
df
# Out:
#         total_bill   tip     sex   day    time  size  tip percentage
# smoker
# No           16.99  1.01  Female   Sun  Dinner     2        5.944673
# No           10.34  1.66    Male   Sun  Dinner     3       16.054159
# No           21.01  3.50    Male   Sun  Dinner     3       16.658734
# No           23.68  3.31    Male   Sun  Dinner     2       13.978041
# No           24.59  3.61  Female   Sun  Dinner     4       14.680765
# ...            ...   ...     ...   ...     ...   ...             ...
# No           29.03  5.92    Male   Sat  Dinner     3       20.392697
# Yes          27.18  2.00  Female   Sat  Dinner     2        7.358352
# Yes          22.67  2.00    Male   Sat  Dinner     2        8.822232
# No           17.82  1.75    Male   Sat  Dinner     2        9.820426
# No           18.78  3.00  Female  Thur  Dinner     2       15.974441
#
# [244 rows x 7 columns]

# %%
df.reset_index()
# Out:
#     smoker  total_bill   tip     sex   day    time  size  tip percentage
# 0       No       16.99  1.01  Female   Sun  Dinner     2        5.944673
# 1       No       10.34  1.66    Male   Sun  Dinner     3       16.054159
# 2       No       21.01  3.50    Male   Sun  Dinner     3       16.658734
# 3       No       23.68  3.31    Male   Sun  Dinner     2       13.978041
# 4       No       24.59  3.61  Female   Sun  Dinner     4       14.680765
# ..     ...         ...   ...     ...   ...     ...   ...             ...
# 239     No       29.03  5.92    Male   Sat  Dinner     3       20.392697
# 240    Yes       27.18  2.00  Female   Sat  Dinner     2        7.358352
# 241    Yes       22.67  2.00    Male   Sat  Dinner     2        8.822232
# 242     No       17.82  1.75    Male   Sat  Dinner     2        9.820426
# 243     No       18.78  3.00  Female  Thur  Dinner     2       15.974441
#
# [244 rows x 8 columns]

# %%
df
# Out:
#         total_bill   tip     sex   day    time  size  tip percentage
# smoker
# No           16.99  1.01  Female   Sun  Dinner     2        5.944673
# No           10.34  1.66    Male   Sun  Dinner     3       16.054159
# No           21.01  3.50    Male   Sun  Dinner     3       16.658734
# No           23.68  3.31    Male   Sun  Dinner     2       13.978041
# No           24.59  3.61  Female   Sun  Dinner     4       14.680765
# ...            ...   ...     ...   ...     ...   ...             ...
# No           29.03  5.92    Male   Sat  Dinner     3       20.392697
# Yes          27.18  2.00  Female   Sat  Dinner     2        7.358352
# Yes          22.67  2.00    Male   Sat  Dinner     2        8.822232
# No           17.82  1.75    Male   Sat  Dinner     2        9.820426
# No           18.78  3.00  Female  Thur  Dinner     2       15.974441
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#         total_bill   tip     sex  day    time  size  tip percentage
# smoker
# No           16.99  1.01  Female  Sun  Dinner     2        5.944673
# No           10.34  1.66    Male  Sun  Dinner     3       16.054159
# No           21.01  3.50    Male  Sun  Dinner     3       16.658734
# No           23.68  3.31    Male  Sun  Dinner     2       13.978041
# No           24.59  3.61  Female  Sun  Dinner     4       14.680765

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 244 entries, No to No
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total_bill      244 non-null    float64
#  1   tip             244 non-null    float64
#  2   sex             244 non-null    object
#  3   day             244 non-null    object
#  4   time            244 non-null    object
#  5   size            244 non-null    int64
#  6   tip percentage  244 non-null    float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 23.4+ KB

# %%
df = df.reset_index()

# %%
df
# Out:
#     smoker  total_bill   tip     sex   day    time  size  tip percentage
# 0       No       16.99  1.01  Female   Sun  Dinner     2        5.944673
# 1       No       10.34  1.66    Male   Sun  Dinner     3       16.054159
# 2       No       21.01  3.50    Male   Sun  Dinner     3       16.658734
# 3       No       23.68  3.31    Male   Sun  Dinner     2       13.978041
# 4       No       24.59  3.61  Female   Sun  Dinner     4       14.680765
# ..     ...         ...   ...     ...   ...     ...   ...             ...
# 239     No       29.03  5.92    Male   Sat  Dinner     3       20.392697
# 240    Yes       27.18  2.00  Female   Sat  Dinner     2        7.358352
# 241    Yes       22.67  2.00    Male   Sat  Dinner     2        8.822232
# 242     No       17.82  1.75    Male   Sat  Dinner     2        9.820426
# 243     No       18.78  3.00  Female  Thur  Dinner     2       15.974441
#
# [244 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   smoker          244 non-null    object
#  1   total_bill      244 non-null    float64
#  2   tip             244 non-null    float64
#  3   sex             244 non-null    object
#  4   day             244 non-null    object
#  5   time            244 non-null    object
#  6   size            244 non-null    int64
#  7   tip percentage  244 non-null    float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 15.4+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   smoker          244 non-null    object
#  1   total_bill      244 non-null    float64
#  2   tip             244 non-null    float64
#  3   sex             244 non-null    object
#  4   day             244 non-null    object
#  5   time            244 non-null    object
#  6   size            244 non-null    int64
#  7   tip percentage  244 non-null    float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 15.4+ KB

# %%
df.iloc[0]
# Out:
# smoker                  No
# total_bill           16.99
# tip                   1.01
# sex                 Female
# day                    Sun
# time                Dinner
# size                     2
# tip percentage    5.944673
# Name: 0, dtype: object

# %%
df.iloc[7]
# Out:
# smoker                   No
# total_bill            26.88
# tip                    3.12
# sex                    Male
# day                     Sun
# time                 Dinner
# size                      4
# tip percentage    11.607143
# Name: 7, dtype: object

# %%
df.iloc[0:4]
# Out:
#   smoker  total_bill   tip     sex  day    time  size  tip percentage
# 0     No       16.99  1.01  Female  Sun  Dinner     2        5.944673
# 1     No       10.34  1.66    Male  Sun  Dinner     3       16.054159
# 2     No       21.01  3.50    Male  Sun  Dinner     3       16.658734
# 3     No       23.68  3.31    Male  Sun  Dinner     2       13.978041

# %%
df.iloc[6:]
# Out:
#     smoker  total_bill   tip     sex   day    time  size  tip percentage
# 6       No        8.77  2.00    Male   Sun  Dinner     2       22.805017
# 7       No       26.88  3.12    Male   Sun  Dinner     4       11.607143
# 8       No       15.04  1.96    Male   Sun  Dinner     2       13.031915
# 9       No       14.78  3.23    Male   Sun  Dinner     2       21.853857
# 10      No       10.27  1.71    Male   Sun  Dinner     2       16.650438
# ..     ...         ...   ...     ...   ...     ...   ...             ...
# 239     No       29.03  5.92    Male   Sat  Dinner     3       20.392697
# 240    Yes       27.18  2.00  Female   Sat  Dinner     2        7.358352
# 241    Yes       22.67  2.00    Male   Sat  Dinner     2        8.822232
# 242     No       17.82  1.75    Male   Sat  Dinner     2        9.820426
# 243     No       18.78  3.00  Female  Thur  Dinner     2       15.974441
#
# [238 rows x 8 columns]

# %%
df = df.iloc[1:]

# %%
df
# Out:
#     smoker  total_bill   tip     sex   day    time  size  tip percentage
# 1       No       10.34  1.66    Male   Sun  Dinner     3       16.054159
# 2       No       21.01  3.50    Male   Sun  Dinner     3       16.658734
# 3       No       23.68  3.31    Male   Sun  Dinner     2       13.978041
# 4       No       24.59  3.61  Female   Sun  Dinner     4       14.680765
# 5       No       25.29  4.71    Male   Sun  Dinner     4       18.623962
# ..     ...         ...   ...     ...   ...     ...   ...             ...
# 239     No       29.03  5.92    Male   Sat  Dinner     3       20.392697
# 240    Yes       27.18  2.00  Female   Sat  Dinner     2        7.358352
# 241    Yes       22.67  2.00    Male   Sat  Dinner     2        8.822232
# 242     No       17.82  1.75    Male   Sat  Dinner     2        9.820426
# 243     No       18.78  3.00  Female  Thur  Dinner     2       15.974441
#
# [243 rows x 8 columns]

# %%
one_row = df.iloc[0]

# %%
one_row
# Out:
# smoker                   No
# total_bill            10.34
# tip                    1.66
# sex                    Male
# day                     Sun
# time                 Dinner
# size                      3
# tip percentage    16.054159
# Name: 1, dtype: object

# %%
df = df.append(one_row)

# %%
df
# Out:
#     smoker  total_bill   tip     sex   day    time  size  tip percentage
# 1       No       10.34  1.66    Male   Sun  Dinner     3       16.054159
# 2       No       21.01  3.50    Male   Sun  Dinner     3       16.658734
# 3       No       23.68  3.31    Male   Sun  Dinner     2       13.978041
# 4       No       24.59  3.61  Female   Sun  Dinner     4       14.680765
# 5       No       25.29  4.71    Male   Sun  Dinner     4       18.623962
# ..     ...         ...   ...     ...   ...     ...   ...             ...
# 240    Yes       27.18  2.00  Female   Sat  Dinner     2        7.358352
# 241    Yes       22.67  2.00    Male   Sat  Dinner     2        8.822232
# 242     No       17.82  1.75    Male   Sat  Dinner     2        9.820426
# 243     No       18.78  3.00  Female  Thur  Dinner     2       15.974441
# 1       No       10.34  1.66    Male   Sun  Dinner     3       16.054159
#
# [244 rows x 8 columns]

# %%
dollars_greater_than_30 = df['total_bill'] > 30

# %%
dollars_greater_than_30
# Out:
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 240    False
# 241    False
# 242    False
# 243    False
# 1      False
# Name: total_bill, Length: 244, dtype: bool

# %%
df[dollars_greater_than_30]
# Out:
#     smoker  total_bill    tip     sex   day    time  size  tip percentage
# 11      No       35.26   5.00  Female   Sun  Dinner     4       14.180374
# 23      No       39.42   7.58    Male   Sat  Dinner     4       19.228818
# 39      No       31.27   5.00    Male   Sat  Dinner     3       15.989767
# 44      No       30.40   5.60    Male   Sun  Dinner     4       18.421053
# 47      No       32.40   6.00    Male   Sun  Dinner     4       18.518519
# 52      No       34.81   5.20  Female   Sun  Dinner     4       14.938236
# 56     Yes       38.01   3.00    Male   Sat  Dinner     4        7.892660
# 59      No       48.27   6.73    Male   Sat  Dinner     4       13.942407
# 83     Yes       32.68   5.00    Male  Thur   Lunch     2       15.299878
# 85      No       34.83   5.17  Female  Thur   Lunch     4       14.843526
# 95     Yes       40.17   4.73    Male   Fri  Dinner     4       11.774956
# 102    Yes       44.30   2.50  Female   Sat  Dinner     3        5.643341
# ...

# %%
df[df['total_bill'] > 30]
# Out:
#     smoker  total_bill    tip     sex   day    time  size  tip percentage
# 11      No       35.26   5.00  Female   Sun  Dinner     4       14.180374
# 23      No       39.42   7.58    Male   Sat  Dinner     4       19.228818
# 39      No       31.27   5.00    Male   Sat  Dinner     3       15.989767
# 44      No       30.40   5.60    Male   Sun  Dinner     4       18.421053
# 47      No       32.40   6.00    Male   Sun  Dinner     4       18.518519
# 52      No       34.81   5.20  Female   Sun  Dinner     4       14.938236
# 56     Yes       38.01   3.00    Male   Sat  Dinner     4        7.892660
# 59      No       48.27   6.73    Male   Sat  Dinner     4       13.942407
# 83     Yes       32.68   5.00    Male  Thur   Lunch     2       15.299878
# 85      No       34.83   5.17  Female  Thur   Lunch     4       14.843526
# 95     Yes       40.17   4.73    Male   Fri  Dinner     4       11.774956
# 102    Yes       44.30   2.50  Female   Sat  Dinner     3        5.643341
# ...

# %%
df[df['sex'] == 'Male']
# Out:
#     smoker  total_bill   tip   sex  day    time  size  tip percentage
# 1       No       10.34  1.66  Male  Sun  Dinner     3       16.054159
# 2       No       21.01  3.50  Male  Sun  Dinner     3       16.658734
# 3       No       23.68  3.31  Male  Sun  Dinner     2       13.978041
# 5       No       25.29  4.71  Male  Sun  Dinner     4       18.623962
# 6       No        8.77  2.00  Male  Sun  Dinner     2       22.805017
# ..     ...         ...   ...   ...  ...     ...   ...             ...
# 237    Yes       32.83  1.17  Male  Sat  Dinner     2        3.563814
# 239     No       29.03  5.92  Male  Sat  Dinner     3       20.392697
# 241    Yes       22.67  2.00  Male  Sat  Dinner     2        8.822232
# 242     No       17.82  1.75  Male  Sat  Dinner     2        9.820426
# 1       No       10.34  1.66  Male  Sun  Dinner     3       16.054159
#
# [158 rows x 8 columns]

# %%
df[df['size'] > 3]
# Out:
#     smoker  total_bill   tip     sex   day    time  size  tip percentage
# 4       No       24.59  3.61  Female   Sun  Dinner     4       14.680765
# 5       No       25.29  4.71    Male   Sun  Dinner     4       18.623962
# 7       No       26.88  3.12    Male   Sun  Dinner     4       11.607143
# 11      No       35.26  5.00  Female   Sun  Dinner     4       14.180374
# 13      No       18.43  3.00    Male   Sun  Dinner     4       16.277808
# 23      No       39.42  7.58    Male   Sat  Dinner     4       19.228818
# 25      No       17.81  2.34    Male   Sat  Dinner     4       13.138686
# 31      No       18.35  2.50    Male   Sat  Dinner     4       13.623978
# 33      No       20.69  2.45  Female   Sat  Dinner     4       11.841469
# 44      No       30.40  5.60    Male   Sun  Dinner     4       18.421053
# 47      No       32.40  6.00    Male   Sun  Dinner     4       18.518519
# 52      No       34.81  5.20  Female   Sun  Dinner     4       14.938236
# ...

# %%
1 == 1 and 2 == 2
# Out:
# True

# %%
1 == 1 or 2 > 1
# Out:
# True

# %%
df['total_bill'] > 30
df['sex'] == 'Male'
# Out:
# 1       True
# 2       True
# 3       True
# 4      False
# 5       True
#        ...
# 240    False
# 241     True
# 242     True
# 243    False
# 1       True
# Name: sex, Length: 244, dtype: bool

# %%
df[(df['total_bill'] > 30) & (df['sex'] == 'Male')]
# Out:
#     smoker  total_bill    tip   sex   day    time  size  tip percentage
# 23      No       39.42   7.58  Male   Sat  Dinner     4       19.228818
# 39      No       31.27   5.00  Male   Sat  Dinner     3       15.989767
# 44      No       30.40   5.60  Male   Sun  Dinner     4       18.421053
# 47      No       32.40   6.00  Male   Sun  Dinner     4       18.518519
# 56     Yes       38.01   3.00  Male   Sat  Dinner     4        7.892660
# 59      No       48.27   6.73  Male   Sat  Dinner     4       13.942407
# 83     Yes       32.68   5.00  Male  Thur   Lunch     2       15.299878
# 95     Yes       40.17   4.73  Male   Fri  Dinner     4       11.774956
# 112     No       38.07   4.00  Male   Sun  Dinner     3       10.506961
# 141     No       34.30   6.70  Male  Thur   Lunch     6       19.533528
# 142     No       41.19   5.00  Male  Thur   Lunch     5       12.138869
# 156     No       48.17   5.00  Male   Sun  Dinner     6       10.379905
# ...

# %%
df.head()
# Out:
#   smoker  total_bill   tip     sex  day    time  size  tip percentage
# 1     No       10.34  1.66    Male  Sun  Dinner     3       16.054159
# 2     No       21.01  3.50    Male  Sun  Dinner     3       16.658734
# 3     No       23.68  3.31    Male  Sun  Dinner     2       13.978041
# 4     No       24.59  3.61  Female  Sun  Dinner     4       14.680765
# 5     No       25.29  4.71    Male  Sun  Dinner     4       18.623962

# %%
options = ['Sat','Sun']

# %%
[df['day'].isin(options)]
# Out:
# [1       True
#  2       True
#  3       True
#  4       True
#  5       True
#         ...
#  240     True
#  241     True
#  242     True
#  243    False
#  1       True
#  Name: day, Length: 244, dtype: bool]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 244 entries, 1 to 1
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   smoker          244 non-null    object
#  1   total_bill      244 non-null    float64
#  2   tip             244 non-null    float64
#  3   sex             244 non-null    object
#  4   day             244 non-null    object
#  5   time            244 non-null    object
#  6   size            244 non-null    int64
#  7   tip percentage  244 non-null    float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 17.2+ KB

# %%
df.head()
# Out:
#   smoker  total_bill   tip     sex  day    time  size  tip percentage
# 1     No       10.34  1.66    Male  Sun  Dinner     3       16.054159
# 2     No       21.01  3.50    Male  Sun  Dinner     3       16.658734
# 3     No       23.68  3.31    Male  Sun  Dinner     2       13.978041
# 4     No       24.59  3.61  Female  Sun  Dinner     4       14.680765
# 5     No       25.29  4.71    Male  Sun  Dinner     4       18.623962

# %%
def last_four(num):
  return str(num)[4:]

# %%
last_four(123456789)
# Out:
# '56789'

# %%
df['total_bill']
# Out:
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
# 5      25.29
#        ...
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# 1      10.34
# Name: total_bill, Length: 244, dtype: float64

# %%
df['total_bill'].mean()
# Out:
# 19.75868852459017

# %%
def yelp(price):
  if price < 10:
    return '$'
  elif price >=10 and price < 30:
    return '$$'
  else:
    return '$$$'

# %%
yelp(35)
# Out:
# '$$$'

# %%
yelp(15)
# Out:
# '$$'

# %%
df['yelp'] = df['total_bill'].apply(yelp)

# %%
df['yelp']
# Out:
# 1      $$
# 2      $$
# 3      $$
# 4      $$
# 5      $$
#        ..
# 240    $$
# 241    $$
# 242    $$
# 243    $$
# 1      $$
# Name: yelp, Length: 244, dtype: object

# %%
df
# Out:
#     smoker  total_bill   tip     sex   day    time  size  tip percentage yelp
# 1       No       10.34  1.66    Male   Sun  Dinner     3       16.054159   $$
# 2       No       21.01  3.50    Male   Sun  Dinner     3       16.658734   $$
# 3       No       23.68  3.31    Male   Sun  Dinner     2       13.978041   $$
# 4       No       24.59  3.61  Female   Sun  Dinner     4       14.680765   $$
# 5       No       25.29  4.71    Male   Sun  Dinner     4       18.623962   $$
# ..     ...         ...   ...     ...   ...     ...   ...             ...  ...
# 240    Yes       27.18  2.00  Female   Sat  Dinner     2        7.358352   $$
# 241    Yes       22.67  2.00    Male   Sat  Dinner     2        8.822232   $$
# 242     No       17.82  1.75    Male   Sat  Dinner     2        9.820426   $$
# 243     No       18.78  3.00  Female  Thur  Dinner     2       15.974441   $$
# 1       No       10.34  1.66    Male   Sun  Dinner     3       16.054159   $$
#
# [244 rows x 9 columns]
